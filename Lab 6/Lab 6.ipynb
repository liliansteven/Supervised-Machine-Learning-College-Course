# %% [markdown]
# # Regulrization
# This is a form of regression, that constrains/ regularizes or shrinks the coefficient estimates towards zero. In other words, this technique discourages learning a more complex or flexible model, so as to avoid the risk of **overfitting**.
#
# The regularizaiton is adding penality to the weights in the cost function, so while training the training will try to shrink the weights values, hence reducing the overfitting
#
# - L1 Regularization, also called a lasso regression, adds the “absolute value of magnitude” of the coefficient as a penalty term to the loss function.
# - L2 Regularization, also called a ridge regression, adds the “squared magnitude” of the coefficient as the penalty term to the loss function.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### L1 and L2 using gradient descent
# To use gradient descent, we take the derivative of the cost function
# so using L1 and L2, each will have different update rule for the weights

# %% [markdown]
# **L1** update rule with gradient descent
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **L2** update rule with gradient descent
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So, if the model is overfitting some data points we can solve this problem using regularization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Optimizers
# The optimizer algorithms are a type of optimization method that helps improve a deep learning model’s performance, while trying to reach the best weights of a function through minmizing it

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Gradient descent variants
# Gradient descent works best for most purposes. However, it has some downsides too. It is expensive to calculate the gradients if the size of the data is huge. Gradient descent works well for convex functions, but it doesn’t know how far to travel along the gradient for nonconvex functions.
#
# ## Stochastic gradient descent (SGD)
#
# The gradient descent on massive data might not be the best option. A solution for this is stochastic gradient descent, instead of taking the whole dataset for each iteration, we randomly select the batches of data. That means we only take a few samples from the dataset.
# - the path taken by the algorithm is full of noise
# -  SGD uses a higher number of iterations
# - the computation cost is still less than that of the gradient descent optimizer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Stochastic gradient descent with momentum
# ### Momentum
# A very popular technique that is used along with SGD is called Momentum. Instead of using only the gradient of the current step to guide the search, momentum also accumulates the gradient of the past steps to determine the direction to go
#
#
# As SGD takes a much more noisy path than the GD algorithm. it requires a more significant number of iteration, What the momentum does is helping in faster convergence of the loss function. SGD oscillates between either direction of the gradient and updates the weights accordingly. However, adding a fraction of the previous update to the current update will make the process a bit faster.
# - learning rate should be decreased with a high momentum term

# %% [markdown]
# ## RMS Prob
#
# Beta is a small number e.g. 0.99
#
# dw is the normal weight update rule but unbiased, divided by (1-beta^t)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Adam Optimizer

# %% [markdown]
# ![image.png](data:image/png;base64,...)
